# %% [markdown]
# # ViralScope — Exploratory Data Analysis
#
# **Pipeline stage:** post-data-collection, pre-feature-engineering.
#
# **Goal:** understand each platform's engagement distribution, validate the top-5%-at-5-days virality threshold, and surface signals worth turning into features.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
sns.set_theme(style='whitegrid')
pd.set_option('display.max_columns', 50)

# %% [markdown]
# ## 1. Load raw data
#
# _Populate once data collection completes (see `src/`)._

# %%
# twitter = pd.read_parquet('../data/raw/twitter.parquet')
# reddit  = pd.read_parquet('../data/raw/reddit.parquet')
# tiktok  = pd.read_parquet('../data/raw/tiktok.parquet')
# youtube = pd.read_parquet('../data/raw/youtube.parquet')

# %% [markdown]
# ## 2. Engagement-rate distribution per platform
#
# Confirm the top-5% threshold lands somewhere sensible (not a single outlier, not noise) before locking labels.

# %% [markdown]
# ## 3. Class balance check
#
# Verify ~5% positive rate per platform and total positive count (target: >=1,000 per platform).

# %% [markdown]
# ## 4. Initial signal hunt
#
# Compare viral vs. non-viral on: post hour, day-of-week, caption length, hashtag count, account size, sentiment.
